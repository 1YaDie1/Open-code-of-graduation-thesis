# %%
import pandas as pd  
  
# 读取CSV文件  
df1 = pd.read_csv('./爬取B站0基础学习python课程数据v3.csv')  
  
# 提取最后三列  
last_three_columns = df1.iloc[:,:]  
  
# 将数据写入Excel文件  
last_three_columns.to_excel('爬取B站0基础学习python课程数据v3.xlsx', index=False)

# %%
# 读取CSV文件  
df2 = pd.read_csv('./爬取B站0基础学习python课程数据v3.csv')  
df2
# Out:
#      id编号                                                 标题   点赞数量   投币数量  \
# 0       1                【Python教程】《零基础入门学习Python》最新版（完结撒花🎉）  17.0万  15.2万
# 1       2         黑马程序员python教程，8天python从入门到精通，学python看这套就够了  12.1万  10.7万
# 2       3  【全站最系统】冒死上传B站最全Python课程，整整三百集！价值3W的课程现在免费分享给大家...   8386   4743
# 3       4                                   20分钟学完一遍python基础   5918   2693
# 4       5  【B站最全最易学】华为公司终于将Python整理成了漫画书，漫画教学更生动，小白一学就会，拿...   4087   2574
# ..    ...                                                ...    ...    ...
# 195   196  Python学习，没有电脑也能学好的编程的宝藏软件，我学编程的时候怎么没有遇到这个软件 干货...     70     81
# 196   197  【python基础】2023零基础学习python，python处理excel自动化办公小工...   1177    529
# 197   198                                       学Python有哪些用途    702    181
# 198   199  全套Python教程_Python基础入门视频教程，零基础小白自学Python入门教程（会打...     31     21
# 199   200  【python基础】2022零基础学习python，python处理excel自动化办公小工...    119     65
#
# ...

# %%
biaoti = df2.loc[0:99,'标题']
biaoti
# Out:
# 0                   【Python教程】《零基础入门学习Python》最新版（完结撒花🎉）
# 1            黑马程序员python教程，8天python从入门到精通，学python看这套就够了
# 2     【全站最系统】冒死上传B站最全Python课程，整整三百集！价值3W的课程现在免费分享给大家...
# 3                                      20分钟学完一遍python基础
# 4     【B站最全最易学】华为公司终于将Python整理成了漫画书，漫画教学更生动，小白一学就会，拿...
#                             ...
# 95                              【2023新版】Python零基础入门自学教程
# 96         【新手必看】用一周时间刷爆这100道Python基础练习题，你的技术绝对不比大牛差！！！
# 97    编程大佬196小时讲完的Python全套教程，整整300集，全程干货无废话，零基础入门学习P...
# 98     【人工智能】Python是最好的语言！零基础学习Python机器学习，打造最好机械学习技术教学！
# 99    字节大佬一周讲完的Python，学完即就业，小白信手拈来，拿走不谢，允许白嫖！Python基...
# Name: 标题, Length: 100, dtype: object

# %%
df = pd.read_excel("./评论数据.xlsx")

# %%
df
# Out:
#                                                   评论1  \
# 0   置顶\n本系列视频配套教材：\n零基础入门学习Python 小甲鱼 python编程从入门到...
# 1   置顶\n教程配套资料关注微信公众号：黑马程序员，回复：领取资源02\n点赞，转发+收藏，关注...
# 2   置顶\n领取视频资料的同学请\n➕V：【riyu2324】备注：课程，先到先得哦！\n请认准...
# 3                        3:09处，应为print(s1+s2*3) #OHHH
# 4              置顶\nPython & pycharm安装包，学习思路，   留个“1”～
# ..                                                ...
# 95  置顶\n需要文档资料的同学们，请支持一个后评论区留言“学习”，UP会挨个私发消息的啦！祝大家...
# 96  置顶\n教程只做技术分享，仅供个人学习研究！配套资料^允许礼貌白嫖，留下：“666”，UP都...
# 97  置顶\n全套Python学习资料➡️评论“学习”，私信给我回个“学习”，“三连➕关🐷”领取资...
# 98                                       置顶\n资料在简介处领取
# 99  置顶\n资料获取方式：\n1.点击链接直接获取：https://www.bilibili.c...
#
#                                                   评论2  \
# 0   基础系列\n【完结】：【Python教程】《零基础入门学习Python》\n【最新】：【Py...
# 1   九九乘法表我码出来的是这样的\na = 1\nb = 0\nwhile b <= 8:\n ...
# 2                                    刚刚高考完 看这个会不会有点快了
# 3   感谢up！！！完全零基础！一晚上跟着这个视频，把上面内容自己在Python打了一遍，然后就上...
# ...

# %%
df.loc[:,'课程标题'] = biaoti
df
# Out:
#                                                   评论1  \
# 0   置顶\n本系列视频配套教材：\n零基础入门学习Python 小甲鱼 python编程从入门到...
# 1   置顶\n教程配套资料关注微信公众号：黑马程序员，回复：领取资源02\n点赞，转发+收藏，关注...
# 2   置顶\n领取视频资料的同学请\n➕V：【riyu2324】备注：课程，先到先得哦！\n请认准...
# 3                        3:09处，应为print(s1+s2*3) #OHHH
# 4              置顶\nPython & pycharm安装包，学习思路，   留个“1”～
# ..                                                ...
# 95  置顶\n需要文档资料的同学们，请支持一个后评论区留言“学习”，UP会挨个私发消息的啦！祝大家...
# 96  置顶\n教程只做技术分享，仅供个人学习研究！配套资料^允许礼貌白嫖，留下：“666”，UP都...
# 97  置顶\n全套Python学习资料➡️评论“学习”，私信给我回个“学习”，“三连➕关🐷”领取资...
# 98                                       置顶\n资料在简介处领取
# 99  置顶\n资料获取方式：\n1.点击链接直接获取：https://www.bilibili.c...
#
#                                                   评论2  \
# 0   基础系列\n【完结】：【Python教程】《零基础入门学习Python》\n【最新】：【Py...
# 1   九九乘法表我码出来的是这样的\na = 1\nb = 0\nwhile b <= 8:\n ...
# 2                                    刚刚高考完 看这个会不会有点快了
# 3   感谢up！！！完全零基础！一晚上跟着这个视频，把上面内容自己在Python打了一遍，然后就上...
# ...

# %%
df.to_excel('./评论数据1.xlsx')

# %%
df_f = pd.read_excel('./评论数据.xlsx')
df_f.head()
# Out:
#                                                 课程标题  \
# 0                【Python教程】《零基础入门学习Python》最新版（完结撒花🎉）
# 1         黑马程序员python教程，8天python从入门到精通，学python看这套就够了
# 2  【全站最系统】冒死上传B站最全Python课程，整整三百集！价值3W的课程现在免费分享给大家...
# 3                                   20分钟学完一遍python基础
# 4  【B站最全最易学】华为公司终于将Python整理成了漫画书，漫画教学更生动，小白一学就会，拿...
#
#                                                  评论1  \
# 0  置顶\n本系列视频配套教材：\n零基础入门学习Python 小甲鱼 python编程从入门到...
# 1  置顶\n教程配套资料关注微信公众号：黑马程序员，回复：领取资源02\n点赞，转发+收藏，关注...
# 2  置顶\n领取视频资料的同学请\n➕V：【riyu2324】备注：课程，先到先得哦！\n请认准...
# 3                       3:09处，应为print(s1+s2*3) #OHHH
# 4             置顶\nPython & pycharm安装包，学习思路，   留个“1”～
#
#                                                  评论2  \
# 0  基础系列\n【完结】：【Python教程】《零基础入门学习Python》\n【最新】：【Py...
# 1  九九乘法表我码出来的是这样的\na = 1\nb = 0\nwhile b <= 8:\n ...
# 2                                   刚刚高考完 看这个会不会有点快了
# 3  感谢up！！！完全零基础！一晚上跟着这个视频，把上面内容自己在Python打了一遍，然后就上...
# ...
